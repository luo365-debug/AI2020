# %% [markdown]
# # 服务器的使用
# - 服务器信息
# - 文件的上传与下载
# - 训练数据命令执行

# %% [markdown]
# ## 服务器信息
# 注意：两个服务器的账号密码一致
# - 服务器IP：106.13.96.26，106.13.68.236
# - 服务器账户：root
# - 服务器密码：qwer123$

# %% [markdown]
# ##  文件的上传与下载

# %% [markdown]
# ### 使用FileZillaClient上传下载
# - 下载FileZillaClient：https://filezilla-project.org/download.php?type=client
# - 安装FileZillaClient
# - 连接服务器
# - 传输文件

# %% [markdown]
# #### 下载FileZillaClient
# - 官方网站：https://filezilla-project.org/download.php?type=client

# %% [markdown]
# ![image.jpg](attachment:image.jpg)

# %% [markdown]
# #### 安装FileZillaClient
# - 点击直接安装

# %% [markdown]
# #### 连接服务器上传下载
# - 连接服务器：填写主机、用户名、密码，连接，如下图
# - 选择文件的上传与下载，如下图：
#     - 上传：选择本地上传文件，右击点击上传
#     - 下载：选择服务器下载文件，右击点击下载

# %% [markdown]
# ![image.jpg](attachment:image.jpg)

# %% [markdown]
# ## 训练数据命令执行
# - shell连接登录服务器
# - 执行训练数据的命令

# %% [markdown]
# ### shell连接登录服务器
# 注意：登录命令：ssh root@ip
# - cmd登录
# - git登录

# %% [markdown]
# #### cmd登录

# %% [markdown]
# ![image.jpg](attachment:image.jpg)

# %% [markdown]
# #### git登录

# %% [markdown]
# ![image.jpg](attachment:image.jpg)

# %% [markdown]
# ### 执行训练数据的命令
# 注意：运行命令: python3 -m 文件名 [参数|可选]
# - cmd运行
# - git运行

# %% [markdown]
# #### cmd 运行

# %% [markdown]
# ![image.jpg](attachment:image.jpg)

# %% [markdown]
# #### git运行

# %% [markdown]
# ![image.jpg](attachment:image.jpg)
